# %%
# Google Colab에서 작업 디렉토리 설정
# %cd /content

# GitHub에서 프로젝트 클론
# !git clone https://github.com/yastrebksv/TennisProject.git

# 프로젝트 폴더로 이동
# %cd TennisProject
# Out:
# /content
# Cloning into 'TennisProject'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 45 (delta 7), reused 7 (delta 7), pack-reused 32 (from 2)
# Receiving objects: 100% (45/45), 5.50 MiB | 18.54 MiB/s, done.
# Resolving deltas: 100% (15/15), done.
# /content/TennisProject

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 MB 12.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 60.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 62.2 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Installing build dependencies ... error
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !cat README.md
# Out:
# # TennisProject
# Tennis analysis using deep learning and machine learning. <br>
# You can check this blog post https://medium.com/@kosolapov.aetp/tennis-analysis-using-deep-learning-and-machine-learning-a5a74db7e2ee for more details
#
# ![](pics/hard.gif)
# ![](pics/grass.gif)
# ![](pics/clay.gif)
#
# ### Ball detection
# TrackNet was used for detecting tennis ball during the game. For more information you can check this repository: https://github.com/yastrebksv/TrackNet. There you can find
# pretrained weights to check the model.
#
# ### Bounce detection
# CatBoostRegressor was used to predict ball's bounces during the game based on ball trajectory detected in the previous step. You can check this pretrained model: https://drive.google.com/file/d/1Eo5HDnAQE8y_FbOftKZ8pjiojwuy2BmJ/view?usp=drive_link
#
# ### Court detection
# ...

# %%
# !head main.py
# Out:
# import cv2
# from court_detection_net import CourtDetectorNet
# import numpy as np
# from court_reference import CourtReference
# from bounce_detector import BounceDetector
# from person_detector import PersonDetector
# from ball_detector import BallDetector
# from utils import scene_detect
# import argparse
# import torch

# %%
# !pip install catboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 10.3 MB/s eta 0:00:00
# ...

# %%
# !pip install scenedetect
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.3/127.3 kB 2.8 MB/s eta 0:00:00
# ...

# %%
# !python main.py
# Out:
# [ WARN:0@7.510] global cap.cpp:164 open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# OpenCV(4.10.0) /io/opencv/modules/videoio/src/cap_images.cpp:300: error: (-215:Assertion failed) !_filename.empty() in function 'open'
#
#
# VideoManager is deprecated and will be removed.
# [None]
# Traceback (most recent call last):
#   File "/content/TennisProject/main.py", line 148, in <module>
#     scenes = scene_detect(args.path_input_video)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/TennisProject/utils.py", line 10, in scene_detect
#     video_manager = VideoManager([path_video])
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/scenedetect/video_manager.py", line 323, in __init__
#     self._cap_list, self._cap_framerate, self._cap_framesize = open_captures(
#                                                                ^^^^^^^^^^^^^^
# ...

# %%
# !python main.py --path_ball_track_model ./models/ball_model.pt \
                --path_court_model ./models/court_model.pt \
                --path_bounce_model ./models/bounce_model.pt \
                --path_input_video ./videos/input.mp4 \
                --path_output_video ./videos/output.mp4
# Out:
# VideoManager is deprecated and will be removed.
# Traceback (most recent call last):
#   File "/content/TennisProject/main.py", line 148, in <module>
#     scenes = scene_detect(args.path_input_video)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/TennisProject/utils.py", line 10, in scene_detect
#     video_manager = VideoManager([path_video])
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/scenedetect/video_manager.py", line 323, in __init__
#     self._cap_list, self._cap_framerate, self._cap_framesize = open_captures(
#                                                                ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/scenedetect/video_manager.py", line 148, in open_captures
#     raise OSError("Video file(s) not found.")
# OSError: Video file(s) not found.

# %%
# Out:
# /bin/bash: line 1: mk: command not found
